# %% [markdown]
# # 🌸 Pandas — zeszyt nr 2: Iris (zadania)
#
# > **Zbiór danych:** `iris.csv` — pomiary 150 kwiatów irysa w trzech gatunkach
# > **Cel:** przećwiczyć samodzielnie to, co poznałeś w zeszycie nr 1 (Titanic)
#
# ---
#
# ### 📋 Kolumny w zbiorze
#
# | Kolumna | Znaczenie |
# |---------|-----------|
# | `sepal length` | długość działki kielicha (cm) |
# | `sepal width`  | szerokość działki kielicha (cm) |
# | `petal length` | długość płatka (cm) |
# | `petal width`  | szerokość płatka (cm) |
# | `species`      | gatunek: `Iris-setosa`, `Iris-versicolor`, `Iris-virginica` |
#
# ⚠️ **Uwaga:** nazwy kolumn zawierają **spacje**, więc odwołujemy się do nich przez nawiasy kwadratowe — `dataset['sepal length']` — a **nie** przez kropkę (`dataset.sepal length` nie zadziała).

# %% [markdown]
# ## ▶️ Najpierw uruchom tę komórkę — wczytanie danych
#
# Wszystkie zadania korzystają z `DataFrame` o nazwie `dataset`.

# %%
import pandas as pd

dataset = pd.read_csv('iris.csv')
dataset

# %% [markdown]
# ## 🎯 Zadania
#
# Rozwiąż każde zadanie samodzielnie. Podpowiedź i rozwiązanie odsłaniaj dopiero, gdy utkniesz.
#
# ---
#
# ### Zadanie 1 — *wybór kolumn*
# Wyświetl tabelę zawężoną tylko do kolumn `sepal length`, `petal length` i `species`.
#
# <details><summary>💡 Podpowiedź</summary>
#
# Podaj **listę** nazw kolumn w nawiasach kwadratowych: `dataset[[ ... ]]`.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset[['sepal length', 'petal length', 'species']]
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 1:

# %% [markdown]
# ### Zadanie 2 — *pierwszy rzut oka*
# Wyświetl **ostatnie 10** wierszy zbioru.
#
# <details><summary>💡 Podpowiedź</summary>
#
# Metoda `tail()` przyjmuje liczbę wierszy jako argument.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset.tail(10)
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 2:

# %% [markdown]
# ### Zadanie 3 — *typy i braki danych*
# Sprawdź, **ile braków danych (`NaN`)** ma kolumna `petal width`. *(Iris to zbiór kompletny — wynik powinien wyjść `0`.)*
#
# <details><summary>💡 Podpowiedź</summary>
#
# Połącz `isna()` z `sum()` na pojedynczej kolumnie: `dataset['petal width']`.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset['petal width'].isna().sum()
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 3:

# %% [markdown]
# ### Zadanie 4 — *sortowanie*
# Posortuj kwiaty **malejąco wg długości płatka** (`petal length`) i wyświetl **5 z najdłuższymi płatkami**.
#
# <details><summary>💡 Podpowiedź</summary>
#
# Użyj `sort_values(by=..., ascending=False)`, a na końcu dołóż `.head(5)`.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset.sort_values(by='petal length', ascending=False).head(5)
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 4:

# %% [markdown]
# ### Zadanie 5 — *filtrowanie*
# Wyświetl tylko kwiaty gatunku **`Iris-setosa`**, które mają **`sepal length` większe niż 5** (dwa warunki naraz).
#
# <details><summary>💡 Podpowiedź</summary>
#
# Połącz dwa warunki operatorem `&` i pamiętaj o nawiasach: `dataset[(warunek1) & (warunek2)]`.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset[(dataset['species'] == 'Iris-setosa') & (dataset['sepal length'] > 5)]
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 5:

# %% [markdown]
# ### Zadanie 6 — *zliczanie wartości*
# Policz, **ile kwiatów należy do każdego gatunku** (`species`).
#
# <details><summary>💡 Podpowiedź</summary>
#
# Metoda `value_counts()` na kolumnie `species`.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset['species'].value_counts()
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 6:

# %% [markdown]
# ### Zadanie 7 — *statystyki*
# Oblicz **średnią szerokość działki kielicha** (`sepal width`).
#
# <details><summary>💡 Podpowiedź</summary>
#
# Pełne podsumowanie da `describe()`, ale samą średnią policzysz metodą `mean()` na kolumnie.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset['sepal width'].mean()
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 7:

# %% [markdown]
# ### Zadanie 8 — *powrót do Pythona*
# Zamień pierwsze **5 wierszy** zbioru na **listę słowników** (format jak JSON).
#
# <details><summary>💡 Podpowiedź</summary>
#
# Połącz `head(5)` z `to_dict('records')`.
# </details>
#
# <details><summary>✅ Rozwiązanie</summary>
#
# ```python
# dataset.head(5).to_dict('records')
# ```
# </details>

# %%
# Twoje rozwiązanie zadania 8:
